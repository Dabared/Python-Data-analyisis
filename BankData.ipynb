# %%
loan_amount = 100
loan_interest = 0.1
print("Interest Paid =",loan_amount*loan_interest)
# Out:
# Interest Paid = 10.0

# %% [markdown]
# ### Pandas As Analysis
#
# Term Depoisit data
#
# ![image.png](attachment:0062ced6-b596-4845-89ce-685233e03150.png)

# %% [markdown]
# ![image.png](attachment:c8604b95-4a9c-4333-a5bf-a46930ee8c23.png)

# %% [markdown]
# ![image.png](attachment:0b6e782c-2efe-4448-9740-eb575a29c617.png)

# %%
import pandas as pd

# %% [markdown]
# How to import the data to working enivroment ?
#
# Pandas has tool import Data
# e.g function read_cvs("bankdata_1_cvs")

# %%
data =pd.read_csv("bankdata_1.csv")

# %%
data
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# How to gent the coloum Name
#
# We use attribute of the Dataframe called "Coloums"

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %% [markdown]
# data.head(10)

# %% [markdown]
# Refer to the method "info()" in dataFrame and describe its funcation

# %%
data.info
# Out:
# <bound method DataFrame.info of       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
print(bankdata_1.info())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 print(bankdata_1.info())
#
# NameError: name 'bankdata_1' is not defined

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %%
data.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %% [markdown]
# data.age # using name of the the colomns as attribute

# %%
data.age
# Out:
# 0       30
# 1       33
# 2       35
# 3       30
# 4       59
#         ..
# 4516    33
# 4517    57
# 4518    57
# 4519    28
# 4520    44
# Name: age, Length: 4521, dtype: int64

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data.age)
# Out:
# pandas.core.series.Series

# %% [markdown]
#  how to get value counts of the customer who are belonging to different marital statues?
#
# Hit  see pandas documentation value count

# %%
data.value_counts("marital")
# Out:
# marital
# married     2797
# single      1196
# divorced     528
# Name: count, dtype: int64

# %%
data.value_counts("education")
# Out:
# education
# secondary    2306
# tertiary     1350
# primary       678
# unknown       187
# Name: count, dtype: int64

# %% [markdown]
# data['marital'].value_counts()

# %% [markdown]
# Exercise
#
# What are the value counts of the "eduction", housing" and "loan"
# What is maxium account balance ?
# WHat is the age of the customer who has the maxium account balance ?
# What is education leveal ofv the person who has the minum account balance?
# How any customer are there, who are having above average balance?

# %%
data.value_counts("education")
# Out:
# education
# secondary    2306
# tertiary     1350
# primary       678
# unknown       187
# Name: count, dtype: int64

# %%
data.value_counts("housing")
# Out:
# housing
# yes    2559
# no     1962
# Name: count, dtype: int64

# %%
data.value_counts("loan")
# Out:
# loan
# no     3830
# yes     691
# Name: count, dtype: int64

# %%
data.max
# Out:
# <bound method DataFrame.max of       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
data["balance"].max
# Out:
# <bound method Series.max of 0       1787
# 1       4789
# 2       1350
# 3       1476
# 4          0
#         ...
# 4516    -333
# 4517   -3313
# 4518     295
# 4519    1137
# 4520    1136
# Name: balance, Length: 4521, dtype: int64>

# %%
data[['education','housing','loan']].value.counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19016\318540747.py in ?()
# ----> 1 data[['education','housing','loan']].value.counts()
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'value'

# %%
mbalance = data.balance.max()
mbalance
# Out:
# 71188

# %%
data.age[data.balance ==data.balance.max()]
# Out:
# 3700    60
# Name: age, dtype: int64

# %%
data.education[data.balance == data.balance.min()]
# Out:
# 4517    tertiary
# Name: education, dtype: object

# %%
data.balance[data.balance >=data.balance.mean()].count()
# Out:
# 1162

# %% [markdown]
# #sorting

# %%
data.sort_values("age")
# Out:
#       age      job   marital  education default  balance housing loan  \
# 503    19  student    single    primary      no      103      no   no
# 1900   19  student    single    unknown      no        0      no   no
# 2780   19  student    single  secondary      no      302      no   no
# 3233   19  student    single    unknown      no     1169      no   no
# 999    20  student    single  secondary      no      291      no   no
# ...   ...      ...       ...        ...     ...      ...     ...  ...
# 1349   83  retired   married    primary      no      425      no   no
# 4388   83  retired  divorced    primary      no     1097      no   no
# 4108   84  retired  divorced    primary      no      639      no   no
# 1866   86  retired   married  secondary      no     1503      no   no
# 3311   87  retired   married    primary      no      230      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %% [markdown]
# data.sort_values(by ="age",ascending

# %% [markdown]
# What is:
#
# Maximum call Duration ?
# Average Call duration ?
# Standard Deviation of call duration

# %%
data.duration.max()
# Out:
# 3025

# %%
print("maximum call duration =" , data.duration.mean())
# Out:
# maximum call duration = 263.96129174961294

# %%
print("srd call duration =" , data.duration.std())
# Out:
# srd call duration = 259.85663262468205

# %%
counts = data.marital.value_counts()
print(type(counts))
counts.index
print("single precentage=",counts.single/sum(counts)*100)
# Out:
# <class 'pandas.core.series.Series'>
# single precentage= 26.454324264543246

# %%
pt =data.pivot_table(["age","duration"],
                 ["job"],
                 aggfunc ="mean")

# %%
type(pt)
pt.plot.bar()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[79], line 2
#       1 type(pt)
# ----> 2 pt.plot.bar()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\plotting\_core.py:1192, in PlotAccessor.bar(self, x, y, **kwargs)
#    1102 @Appender(
#    1103     """
#    1104     See Also
#    (...)
#    1181     self, x: Hashable | None = None, y: Hashable | None = None, **kwargs
#    1182 ) -> PlotAccessor:
#    1183     """
#    1184     Vertical bar plot.
#    1185
#    (...)
#    1190     other axis represents a measured value.
#    1191     """
# -> 1192     return self(kind="bar", x=x, y=y, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\plotting\_core.py:947, in PlotAccessor.__call__(self, *args, **kwargs)
#     946 def __call__(self, *args, **kwargs):
# ...

# %%
import matplotlib as ps

# %%
type(pt)
pt.plot.bar()
# Out:
# <Axes: xlabel='job'>

# %%
pt = data.value_counts("marital")

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11384\1492609813.py in ?()
# ----> 1 data.value_Counts()
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'value_Counts'

# %%
type(pt)
pt.plot.bar()
# Out:
# <Axes: xlabel='marital'>

# %%
ms = data.pivot_table(["primary"],
                 ["marital"],
                 aggfunc ="mean")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 ms =data.pivot_table(["primary"],
#       2                  ["marital"],
#       3                  aggfunc ="mean")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:9509, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9492 @Substitution("")
#    9493 @Appender(_shared_docs["pivot_table"])
#    9494 def pivot_table(
#    (...)
#    9505     sort: bool = True,
#    9506 ) -> DataFrame:
#    9507     from pandas.core.reshape.pivot import pivot_table
# -> 9509     return pivot_table(
#    9510         self,
#    9511         values=values,
#    9512         index=index,
#    9513         columns=columns,
#    9514         aggfunc=aggfunc,
#    9515         fill_value=fill_value,
# ...

# %%
marital_status_primery_eduction = data.marital[data.education == 'primary']
marital_status_primery_eduction
# Out:
# 0        married
# 9        married
# 18        single
# 26       married
# 36      divorced
#           ...
# 4480     married
# 4485     married
# 4486     married
# 4499    divorced
# 4503     married
# Name: marital, Length: 678, dtype: object

# %%
marital_status_primery_eduction.value_counts().plot.bar()
# Out:
# <Axes: xlabel='marital'>

# %%
data_2 =pd.read_csv("bankdata_2".csv)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 data_2 =pd.read_csv("bankdata_2".csv)
#
# AttributeError: 'str' object has no attribute 'csv'

# %%
data_2 =pd.read_csv("bankdata_2.csv")

# %%
data_2
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
word = "Kushan"
word[42]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 2
#       1 word = "Kushan"
# ----> 2 word[42]
#
# IndexError: string index out of range

# %%
"Ju"+ string_variable
"Ju"+ string_variable + "variable can expanded"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 "Ju"+ string_variable
#       2 "Ju"+ string_variable + "variable can expanded"
#
# NameError: name 'string_variable' is not defined

# %%
squares = [1,2,3,5,6]
print(squares[-1])
# Out:
# 6

# %%
print(squares[1:3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 print(squares[1:3])
#
# NameError: name 'squares' is not defined

# %%
extended_squares = [1,4,9,25,36,49,64,81]

# %%
extended_squares 
extended_squares[1] = 4
extended_squares[2] = 9
extended_squares
# Out:
# [1, 4, 9, 25, 36, 49, 64, 81]

# %%
extended_sequares = [ 1,4,9,36,49,64,81]
extended_sequares
# Out:
# [1, 4, 9, 36, 49, 64, 81]

# %%
extended_sequares = [ 1,4,9,36,49,64,81]
extended_sequares.insert(3,16)

# %%
extended_squares.append(10**2)

# %%
extended_squares
# Out:
# [1, 4, 9, 25, 36, 49, 64, 81, 100]

# %%
extended_squares.append(100)

# %%
extended_squares
# Out:
# [1, 4, 9, 25, 36, 49, 64, 81, 100]

# %%
extended_squares.remove(36)
extended_squares
# Out:
# [1, 4, 9, 25, 49, 64, 81, 100]

# %%
type(new_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 type(new_list)
#
# NameError: name 'new_list' is not defined

# %%
letter =[ 'a','b','c','d','e','f','g']

# %%
x = [a,n]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 x = [a,n]
#
# NameError: name 'a' is not defined

# %%
a = ['a','b','c','d','f','g']

# %%
n = [ 1,2,3,4,4,5]

# %%
x = [a,n]

# %%
x
# Out:
# [['a', 'b', 'c', 'd', 'f', 'g'], [1, 2, 3, 4, 4, 5]]

# %%
x[1][2:4]
# Out:
# [3, 4]

# %%
x[1].append(6)

# %%
x
# Out:
# [['a', 'b', 'c', 'd', 'f', 'g'], [1, 2, 3, 4, 4, 5, 6]]

# %%
number = [ 1,4,5,6,6,5,9]
duplicate =[]
for i in range(0, len(number)):
    for j in range (0, len(number)):
        if number [i] == number[j] and i !=j:
            duplicates.append(numbers[j])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 6
#       4 for j in range (0, len(number)):
#       5     if number [i] == number[j] and i !=j:
# ----> 6         duplicates.append(numbers[j])
#
# NameError: name 'duplicates' is not defined

# %%
number = [1,4,5,9]
hasDuplicates(numbers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 2
#       1 number = [1,4,5,9]
# ----> 2 hasDuplicates(numbers)
#
# NameError: name 'hasDuplicates' is not defined

# %%
def hasDuplicates(numbers):
    seen = set()
    for num in numbers:
        if num in seen:
            return True
        seen.add(num)
    return False

numbers = [1, 4, 5, 9]
print(hasDuplicates(numbers))
# Out:
# False

# %%
def hasDuplicate(elem_list):
    hasDuplicates v = Fales
    for i in range(0, len(elem_list)):
        if number[i] == number[j] and i =j:
            hasDuplicate_v =True
            break

    return has Duplicates_v

# %%
number =[1,4,5,9]
print(numbers , "has duplicates", len (numbers)! =len(set(numbers))
numbers = (1,4,5
